# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('train.csv')
y = df['Survived'].values.reshape(-1,1)
data = df.drop(["Name",'Ticket','Cabin','Embarked','PassengerId','Survived'], axis=1)
data['Age'] = data['Age'].fillna(data['Age'].mean())
data['Sex'] = data['Sex'].map({'male': 1 ,'female':2})
m = data.shape[0]

# %%
sc = StandardScaler()
def sigmoid(z):
    return (1/(1+np.exp(-z)))
def sigmoidder(z):
    return sigmoid(z)*(1-sigmoid(z))
x = data
x = sc.fit_transform(x)

# %%
def initialize_parameters(layer_dims):
    np.random.seed(1)
    L = len(layer_dims)
    W = {}
    b = {}

    for l in range(1, L):
        W[l] = np.random.randn(layer_dims[l], layer_dims[l-1]) * 0.01
        b[l] = np.zeros((layer_dims[l], ))
    
    return W, b

layer_dims = [6, 3, 3, 2, 1]
W, b = initialize_parameters(layer_dims)

# %%
x = data
z = {}
a={}
for i in range(4):
    z[i+1] = np.dot(x,W[i+1].T) + b[i+1]
    a[i+1] = sigmoid(z[i+1])
    print(a[i+1].shape)
    x = a[i+1]
# Out:
# (499, 3)
# (499, 3)
# (499, 2)
# (499, 1)

# %%
print(W[1].shape)
print(x.shape)
print(b[1].shape)
# Out:
# (3, 6)
# (499, 1)
# (3,)
